# %% [markdown]
# <a href="https://colab.research.google.com/github/erpanter/AdvancedTopicsInAI/blob/main/week2/multi_class_image_classification_solution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab Exercise: Multi-class Image Classification
#
# Now that you have learnt how to train a model to do binary image classification of cats and dogs using Convolutional Neural Network.
#
# Modify the code to train a model to recognise whether a hand gesture is one of the gesture in the rock, paper and scissor game.
#
# The dataset of rock paper scissor can be downloaded from https://nyp-aicourse.s3.ap-southeast-1.amazonaws.com/datasets/rps2.zip

# %% [markdown]
# ### Step 1: Import the necessary packages

# %%
import os
import tensorflow as tf
import tensorflow.keras as keras

# %% [markdown]
# ### Step 2: Download Datasets
#
# Download the dataset and unzip the file to a folder.

# %%
dataset_URL = 'https://nyp-aicourse.s3.ap-southeast-1.amazonaws.com/datasets/rps2.zip'
path_to_zip = tf.keras.utils.get_file('rps2.zip', origin=dataset_URL, extract=True, cache_dir='.')
print(path_to_zip)
dataset_dir = os.path.join(os.path.dirname(path_to_zip), 'rps2_extracted/rps2')
# Out:
# ./datasets/rps2_extracted

# %%
print(dataset_dir)
# Out:
# ./datasets/rps2_extracted/rps2

# %% [markdown]
# ### Step 3: Set up your directory.
#
# Examine your dataset folder and set your dataset directory to point to the correct directories.

# %%
train_dir = os.path.join(dataset_dir, "train")
validation_dir = os.path.join(dataset_dir, "validation")

# %% [markdown]
# ### Step 4: Set up the  tf.keras.preprocessing.image_dataset_from_directory()
#
# Set up the  tf.keras.preprocessing.image_dataset_from_directory() for both train and validation set.

# %%
img_height, img_width = 128, 128
batch_size = 32

# resize all the images to the same size as expected by VGG model we downloaded above
image_size = (img_height, img_width)

train_ds = keras.preprocessing.image_dataset_from_directory(
    train_dir,
    image_size=image_size,
    batch_size=batch_size,
    label_mode='int'
)

val_ds = keras.preprocessing.image_dataset_from_directory(
    validation_dir,
    image_size=image_size,
    batch_size=batch_size,
    label_mode='int'
)
# Out:
# Found 2520 files belonging to 3 classes.
# Found 372 files belonging to 3 classes.

# %%
for images, labels in train_ds.take(1):
    print('images shape:', images.shape)
    print('labels shape:', labels.shape)
    print(tf.squeeze(labels))
# Out:
# images shape: (32, 128, 128, 3)
# labels shape: (32,)
# tf.Tensor([2 1 0 1 0 2 1 2 1 1 2 1 2 1 0 1 2 0 0 0 2 0 0 0 2 2 0 2 1 0 0 0], shape=(32,), dtype=int32)

# %% [markdown]
# You can see the labels is **NOT** one-hot-encoded.  Try changing the class_mode to 'categorical' and observe that the label will be one-hot-encoded.

# %% [markdown]
# Print out the class indices so that you know what label is assigned to which class.  Hint: use ``class_names`` of the generator.

# %%
## print out the class indices
print(train_ds.class_names)
print(val_ds.class_names)
# Out:
# ['paper', 'rock', 'scissors']
# ['paper', 'rock', 'scissors']

# %% [markdown]
# ### Step 5: Create your model

# %%
def make_model():

    model = keras.models.Sequential()
    model.add(keras.layers.Input(shape=(128, 128, 3)))
    model.add(keras.layers.Rescaling(scale=1./255))
    model.add(keras.layers.Conv2D(32, (3, 3), activation='relu'))
    model.add(keras.layers.MaxPooling2D((2, 2)))
    model.add(keras.layers.Conv2D(64, (3, 3), activation='relu'))
    model.add(keras.layers.MaxPooling2D((2, 2)))
    model.add(keras.layers.Conv2D(128, (3, 3), activation='relu'))
    model.add(keras.layers.MaxPooling2D((2, 2)))
    model.add(keras.layers.Conv2D(128, (3, 3), activation='relu'))
    model.add(keras.layers.MaxPooling2D((2, 2)))
    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dense(512, activation='relu'))
    model.add(keras.layers.Dense(3, activation='softmax'))

    return model

model = make_model()

# %% [markdown]
# ### Step 6: Compile and Train the Model
#
# Make sure you choose the correct loss function.

# %%
model.compile(loss='sparse_categorical_crossentropy',
              optimizer=keras.optimizers.Adam(learning_rate=1e-4),
              metrics=['accuracy'])

# %% [markdown]
# Visualize your training using Tensorboard.

# %%
def create_tb_callback():

    root_logdir = os.path.join(os.curdir, "tb_logs")

    def get_run_logdir():    # use a new directory for each run
	    import time
	    run_id = time.strftime("run_%Y_%m_%d-%H_%M_%S")
	    return os.path.join(root_logdir, run_id)

    run_logdir = get_run_logdir()

    tb_callback = tf.keras.callbacks.TensorBoard(run_logdir)

    return tb_callback

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath="bestcheckpoint.weights.h5",
    save_weights_only=True,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True)

model.fit(
    train_ds,
    epochs=30,
    validation_data=val_ds,
    callbacks=[create_tb_callback(), model_checkpoint_callback])
# Out:
# Epoch 1/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 16s 117ms/step - accuracy: 0.4987 - loss: 0.9828 - val_accuracy: 0.6532 - val_loss: 0.7704
# Epoch 2/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 75ms/step - accuracy: 0.9328 - loss: 0.2456 - val_accuracy: 0.8414 - val_loss: 0.2721
# Epoch 3/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - accuracy: 0.9940 - loss: 0.0407 - val_accuracy: 0.9516 - val_loss: 0.1827
# Epoch 4/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 73ms/step - accuracy: 0.9970 - loss: 0.0151 - val_accuracy: 0.8575 - val_loss: 0.2401
# Epoch 5/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - accuracy: 0.9990 - loss: 0.0063 - val_accuracy: 0.9194 - val_loss: 0.2178
# Epoch 6/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - accuracy: 0.9996 - loss: 0.0037 - val_accuracy: 0.8978 - val_loss: 0.2242
# Epoch 7/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 9s 59ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.8925 - val_loss: 0.2631
# Epoch 8/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 73ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.8871 - val_loss: 0.2371
# Epoch 9/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 10s 70ms/step - accuracy: 1.0000 - loss: 9.6535e-04 - val_accuracy: 0.8978 - val_loss: 0.2405
# Epoch 10/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 9s 60ms/step - accuracy: 1.0000 - loss: 6.8687e-04 - val_accuracy: 0.8817 - val_loss: 0.2589
# Epoch 11/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 73ms/step - accuracy: 1.0000 - loss: 5.0939e-04 - val_accuracy: 0.8952 - val_loss: 0.2581
# Epoch 12/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 10s 76ms/step - accuracy: 1.0000 - loss: 3.7130e-04 - val_accuracy: 0.8790 - val_loss: 0.2652
# Epoch 13/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 9s 58ms/step - accuracy: 1.0000 - loss: 3.7154e-04 - val_accuracy: 0.8790 - val_loss: 0.2689
# Epoch 14/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 78ms/step - accuracy: 1.0000 - loss: 2.6192e-04 - val_accuracy: 0.8763 - val_loss: 0.2687
# Epoch 15/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 10s 75ms/step - accuracy: 1.0000 - loss: 2.1864e-04 - val_accuracy: 0.8763 - val_loss: 0.2703
# Epoch 16/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - accuracy: 1.0000 - loss: 1.8519e-04 - val_accuracy: 0.8683 - val_loss: 0.2770
# Epoch 17/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - accuracy: 1.0000 - loss: 1.5099e-04 - val_accuracy: 0.8790 - val_loss: 0.2741
# Epoch 18/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 1.0000 - loss: 1.2210e-04 - val_accuracy: 0.8710 - val_loss: 0.2907
# Epoch 19/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - accuracy: 1.0000 - loss: 1.2742e-04 - val_accuracy: 0.8817 - val_loss: 0.2748
# Epoch 20/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 1.0000 - loss: 9.9189e-05 - val_accuracy: 0.8790 - val_loss: 0.2890
# Epoch 21/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 10s 65ms/step - accuracy: 1.0000 - loss: 8.4253e-05 - val_accuracy: 0.8790 - val_loss: 0.2788
# Epoch 22/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 10s 59ms/step - accuracy: 1.0000 - loss: 7.7467e-05 - val_accuracy: 0.8737 - val_loss: 0.2841
# Epoch 23/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 73ms/step - accuracy: 1.0000 - loss: 6.0489e-05 - val_accuracy: 0.8790 - val_loss: 0.2792
# Epoch 24/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - accuracy: 1.0000 - loss: 5.5415e-05 - val_accuracy: 0.8656 - val_loss: 0.2989
# Epoch 25/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 73ms/step - accuracy: 1.0000 - loss: 4.7669e-05 - val_accuracy: 0.8763 - val_loss: 0.2822
# Epoch 26/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - accuracy: 1.0000 - loss: 4.4247e-05 - val_accuracy: 0.8710 - val_loss: 0.2968
# Epoch 27/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - accuracy: 1.0000 - loss: 4.0877e-05 - val_accuracy: 0.8710 - val_loss: 0.3013
# Epoch 28/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - accuracy: 1.0000 - loss: 3.6512e-05 - val_accuracy: 0.8763 - val_loss: 0.2971
# Epoch 29/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 11s 74ms/step - accuracy: 1.0000 - loss: 3.2845e-05 - val_accuracy: 0.8763 - val_loss: 0.3004
# Epoch 30/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - accuracy: 1.0000 - loss: 2.8665e-05 - val_accuracy: 0.8737 - val_loss: 0.3101

# %% [markdown]
# ### Step 7: Save your Model
#
# Save your model for use in inference later on.

# %%
keras.models.save_model(model, filepath="rps_model.keras")

# %% [markdown]
# ### Test your model
#
# The following code cells shows you how to set up Google Colab to take a picture using your webcam. Take a picture of your hand gesture (rock, paper or scissors) and infer using your saved model.

# %%
from IPython.display import display, Javascript
from google.colab.output import eval_js
from base64 import b64decode

def take_photo(filename='photo.jpg', quality=0.8):
  js = Javascript('''
    async function takePhoto(quality) {
      const div = document.createElement('div');
      const capture = document.createElement('button');
      capture.textContent = 'Capture';
      div.appendChild(capture);

      const video = document.createElement('video');
      video.style.display = 'block';
      const stream = await navigator.mediaDevices.getUserMedia({video: true});

      document.body.appendChild(div);
      div.appendChild(video);
      video.srcObject = stream;
      await video.play();

      // Resize the output to fit the video element.
      google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

      // Wait for Capture to be clicked.
      await new Promise((resolve) => capture.onclick = resolve);

      const canvas = document.createElement('canvas');
      canvas.width = video.videoWidth;
      canvas.height = video.videoHeight;
      canvas.getContext('2d').drawImage(video, 0, 0);
      stream.getVideoTracks()[0].stop();
      div.remove();
      return canvas.toDataURL('image/jpeg', quality);
    }
    ''')
  display(js)
  data = eval_js('takePhoto({})'.format(quality))
  binary = b64decode(data.split(',')[1])
  with open(filename, 'wb') as f:
    f.write(binary)
  return filename

# %%
from IPython.display import Image
try:
  filename = take_photo()
  print('Saved to {}'.format(filename))

  # Show the image which was just taken.
  display(Image(filename))
except Exception as err:
  # Errors will be thrown if the user does not have a webcam or if they do not
  # grant the page permission to access it.
  print(str(err))
# Out:
# Saved to photo.jpg

# %% [markdown]
# Write code to read the image and reshape the tensor (to include batch axis) and use your model to predict the label.

# %%
import numpy as np
import tensorflow as tf
import keras

img = keras.preprocessing.image.load_img(
    filename, target_size=(128, 128)
)

# we convert the image to numpy array
img_array = keras.preprocessing.image.img_to_array(img)

# Although we only have single image, however our model expected data in batches
# so we will need to add in the batch axis too
img_array = tf.expand_dims(img_array, 0) # Create a batch

# we load the model saved earlier and do the inference
# Change the filepath to include the .keras extension
model = tf.keras.models.load_model('rps_model.keras')
predicted_label = model.predict(img_array)
# or predicted_label = model(img_array)

print(np.argmax(predicted_label))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step
# 2

# %%
val_ds.class_names
# Out:
# ['paper', 'rock', 'scissors']
